# %% [markdown]
# # Data Analysis #
# This section is for a deep analysis on the correlation between each feature.

# %%
import pandas as pd

df = pd.read_csv("../../Dataset/train.csv")
df
# Out:
#               id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0              1          1  20  50   0.000000   0.083334      0   5.837492
# 1              2          1  20  50   0.033652  18.383041      0   5.907794
# 2              3          1  20  50   0.067514  22.509278      0   7.876254
# 3              4          1  20  50   0.101542  22.808822      0  11.742872
# 4              5          1  20  50   0.135756  25.355850      0  12.234987
# ...          ...        ...  ..  ..        ...        ...    ...        ...
# 6035995  6035996     125749  50  10   2.504603   1.489714      1   3.869032
# 6035996  6035997     125749  50  10   2.537961   1.488497      1   3.869032
# 6035997  6035998     125749  50  10   2.571408   1.558978      1   3.798729
# 6035998  6035999     125749  50  10   2.604744   1.272663      1   4.079938
# 6035999  6036000     125749  50  10   2.638017   1.482739      1   3.869032
#
# [6036000 rows x 8 columns]

# %%
df.dtypes
# Out:
# id             int64
# breath_id      int64
# R              int64
# C              int64
# time_step    float64
# u_in         float64
# u_out          int64
# pressure     float64
# dtype: object

# %% [markdown]
# ## Data distribution ##

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 3, figsize=(20, 16))
axs = axs.flatten()

index = 0
for feature in df:
    ax = axs[index]

    ax.hist(df[feature], bins=30, alpha=0.5, color='blue')
    ax.set_title(feature)
    ax.set_ylabel("Frequency")
    ax.set_title(feature)
    index += 1

for j in range(index, len(axs)):
    axs[j].axis('off')

plt.show()

# %% [markdown]
# ## Pearson correlation ##
# This calculation is to mesure the correlation between each features

# %%
import seaborn as sns

# Calculate the Pearson correlation matrix
corr_matrix = df.corr(method='pearson')

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0)
plt.title("Pearson Correlation Matrix")
plt.show()
